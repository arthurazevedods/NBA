# %%
import pandas as pd
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
import numpy as np

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2023_per_game.html"

# %%
html = requests.get(url)

# %%
html.content
# Out:
# b'\n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/bbr/build" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202211031" />\n    <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertBefore(element, firstScript);\n\t\n\tfunction makeStub() {\n\t    var TCF_LOCATOR_NAME = \'__tcfapiLocator\';\n\t    var queue = [];\n\t    var win = window;\n\t    var cmpFrame;\n\t    \n\t    function addFrame() {\n\t\tvar doc = win.document;\n\t\tvar otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);\n\t\t\n\t\tif (!otherCMP) {\n\t\t    if (doc.body) {\n\t\t\tvar iframe = doc.createElement(\'iframe\');\n\t\t\t\n\t\t\tiframe.style.cssText = \'display:none\';\n\t\t\tiframe.name = TCF_LOCATOR_NAME;\n\t\t\tdoc.body.appendChild(iframe);\n\t\t    } else {\n\t\t\tsetTimeout(addFrame, 5);\n\t\t    }\n\t\t}\n\t\treturn !otherCMP;\n\t    }\n\t    \n\t    function tcfAPIHandler() {\n\t\tvar gdprApplies;\n\t\tvar args = arguments;\n\t\t\n\t\tif (!args.length) {\n\t\t    return queue;\n\t\t} else if (args[0] === \'setGdprApplies\') {\n\t\t    if (\n\t\t\targs.length > 3 &&\n\t\t\t    args[2] === 2 &&\n\t\t\t    typeof args[3] === \'boolean\'\n\t\t    ) {\n\t\t\tgdprApplies = args[3];\n\t\t\tif (typeof args[2] === \'function\') {\n\t\t\t    args[2](\'set\', true);\n\t\t\t}\n\t\t    }\n\t\t} else if (args[0] === \'ping\') {\n\t\t    var retr = {\n\t\t\tgdprApplies: gdprApplies,\n\t\t\tcmpLoaded: false,\n\t\t\tcmpStatus: \'stub\'\n\t\t    };\n\t\t    \n\t\t    if (typeof args[2] === \'function\') {\n\t\t\targs[2](retr);\n\t\t    }\n\t\t} else {\n\t\t    if(args[0] === \'init\' && typeof args[3] === \'object\') {\n\t\t\targs[3] = Object.assign(args[3], { tag_version: \'V2\' });\n\t\t    }\n\t\t    queue.push(args);\n\t\t}\n\t    }\n\t    \n\t    function postMessageEventHandler(event) {\n\t\tvar msgIsString = typeof event.data === \'string\';\n\t\tvar json = {};\n\t\t\n\t\ttry {\n\t\t    if (msgIsString) {\n\t\t\tjson = JSON.parse(event.data);\n\t\t    } else {\n\t\t\tjson = event.data;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tvar payload = json.__tcfapiCall;\n\t\t\n\t\tif (payload) {\n\t\t    window.__tcfapi(\n\t\t\tpayload.command,\n\t\t\tpayload.version,\n\t\t\tfunction(retValue, success) {\n\t\t\t    var returnMsg = {\n\t\t\t\t__tcfapiReturn: {\n\t\t\t\t    returnValue: retValue,\n\t\t\t\t    success: success,\n\t\t\t\t    callId: payload.callId\n\t\t\t\t}\n\t\t\t    };\n\t\t\t    if (msgIsString) {\n\t\t\t\treturnMsg = JSON.stringify(returnMsg);\n\t\t\t    }\n\t\t\t    if (event && event.source && event.source.postMessage) {\n\t\t\t\tevent.source.postMessage(returnMsg, \'*\');\n\t\t\t    }\n\t\t\t},\n\t\t\tpayload.parameter\n\t\t    );\n\t\t}\n\t    }\n\t    \n\t    while (win) {\n\t\ttry {\n\t\t    if (win.frames[TCF_LOCATOR_NAME]) {\n\t\t\tcmpFrame = win;\n\t\t\tbreak;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tif (win === window.top) {\n\t\t    break;\n\t\t}\n\t\twin = win.parent;\n\t    }\n\t    if (!cmpFrame) {\n\t\taddFrame();\n\t\twin.__tcfapi = tcfAPIHandler;\n\t\twin.addEventListener(\'message\', postMessageEventHandler, false);\n\t    }\n\t};\n\t\n\tmakeStub();\n\t\n\tvar uspStubFunction = function() {\n\t    var arg = arguments;\n\t    if (typeof window.__usp ...

# %%
html = urlopen(url)
soup = BeautifulSoup(html)

# %% [markdown]
# ## DataFrame

# %%
#colunas: tags tr
#linhas: tags td
rows = soup.findAll('tr')[1:]
players_stats = [[td.getText() for td in rows[i].findAll('td')] for i in range(len(rows))]

# %%
headers = [th.getText() for th in soup_nba.findAll('tr', limit=2)[0].findAll('th')]
headers
# Out:
# ['Rk',
#  'Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
df_stats = pd.DataFrame(players_stats, columns = headers[1:])

# %%
df_stats.head()
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...   FT%  \
# 0  Precious Achiuwa   C  23  TOR  12   0  20.4  3.0   7.7  .391  ...  .848
# 1      Steven Adams   C  29  MEM  13  13  27.1  3.1   5.0  .615  ...  .310
# 2       Bam Adebayo   C  25  MIA  13  13  34.9  7.3  13.7  .534  ...  .855
# 3      Ochai Agbaji  SG  22  UTA   6   0  11.2  1.3   3.2  .421  ...  .571
# 4      Santi Aldama  PF  22  MEM  14  14  27.7  3.8   8.1  .465  ...  .636
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.0  5.0   7.0  1.3  0.2  0.6  1.3  1.6   8.8
# 1  5.2  6.2  11.4  2.7  0.8  1.2  2.3  2.8   6.8
# 2  2.2  6.9   9.1  3.5  1.2  0.8  3.6  3.5  18.2
# 3  0.7  1.0   1.7  0.2  0.0  0.0  0.0  1.0   3.3
# 4  1.9  4.4   6.2  0.9  0.9  1.2  0.7  2.8   9.8
#
# [5 rows x 29 columns]

# %%
df_stats.tail()
# Out:
#                  Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  \
# 471        Delon Wright  PG  30  WAS   4   0  22.8  2.5   6.0  .417  ...
# 472  McKinley Wright IV  PG  24  DAL   1   0   5.0  1.0   4.0  .250  ...
# 473      Thaddeus Young  PF  34  TOR  11   1  12.7  1.4   2.9  .469  ...
# 474          Trae Young  PG  24  ATL  12  12  35.2  8.6  22.7  .379  ...
# 475         Ivica Zubac   C  25  LAC  13  13  30.6  4.3   7.1  .609  ...
#
#       FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 471  .600  1.0  1.5   2.5  3.3  2.8  1.0  1.0  1.3   6.5
# 472        1.0  1.0   2.0  2.0  1.0  0.0  0.0  0.0   2.0
# 473  .750  1.2  1.5   2.7  1.2  0.9  0.1  0.5  1.1   3.4
# 474  .905  0.9  2.3   3.2  9.3  0.8  0.2  3.8  1.4  27.4
# 475  .605  2.8  8.4  11.2  1.3  0.6  2.2  2.2  2.8  10.6
#
# [5 rows x 29 columns]

# %%
df_stats.shape
# Out:
# (476, 29)

# %% [markdown]
# ## Cleaning

# %%
df_stats.isnull().sum()
# Out:
# Player    22
# Pos       22
# Age       22
# Tm        22
# G         22
# GS        22
# MP        22
# FG        22
# FGA       22
# FG%       22
# 3P        22
# 3PA       22
# 3P%       22
# 2P        22
# 2PA       22
# 2P%       22
# eFG%      22
# FT        22
# FTA       22
# FT%       22
# ORB       22
# DRB       22
# TRB       22
# AST       22
# STL       22
# BLK       22
# TOV       22
# PF        22
# PTS       22
# dtype: int64

# %%
df_stats = df_stats.dropna()
df_stats.isnull().sum()
# Out:
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# dtype: int64

# %%
df_stats.dtypes
# Out:
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
strings = ['Player','Pos','Tm']
        
df_stats = df_stats.apply(pd.to_numeric, errors='ignore')

for df in df_stats:
    if df in [i for i in strings]:
        df_stats[df] = df_stats[df].astype('string')

df_stats.dtypes
# Out:
# Player     string
# Pos        string
# Age         int64
# Tm         string
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %% [markdown]
# ## Players Stats

# %%
mean_games = df_stats.G.mean().round()
mean_games
# Out:
# 9.0

# %%
df_stats = df_stats[df_stats.G >= mean_games]

# %% [markdown]
# ### Top 10 Pointers for position

# %%
df_stats['Pos'].value_counts()
# Out:
# SG    78
# PF    70
# PG    55
# C     50
# SF    47
# Name: Pos, dtype: Int64

# %%
def top_players(df,stats,show_stats=None,top=None):
    
    df = df.sort_values(by=[stats], ascending = False)
    df.index = np.arange(1,len(df) + 1)
    if show_stats == None:
        
        if top == None:
            return df.head(10)
        return df.head(top)
    
    if top == None:
        
        if show_stats == None:
            return df.head(10)
        return df[show_stats].head(10)
        
    return df[show_stats].head(top)

# %% [markdown]
# ### Top 10 Centers

# %%
centers = df_stats[df_stats.Pos == 'C']

# %%
centers = centers.sort_values(by=['PTS'], ascending = False)
centers.index = np.arange(1, len(centers)+1)

centers.head(10)
# Out:
#                 Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 1          Joel Embiid   C   28  PHI  10  10  35.2  10.8  20.1  0.537  ...
# 2        Pascal Siakam   C   28  TOR   9   9  35.7   8.9  18.6  0.479  ...
# 3        Anthony Davis   C   29  LAL  12  12  34.5   9.7  17.8  0.542  ...
# 4         Nikola Jokić   C   27  DEN  13  13  31.1   7.9  13.1  0.606  ...
# 5          Bam Adebayo   C   25  MIA  13  13  34.9   7.3  13.7  0.534  ...
# 6       Alperen Şengün   C   20  HOU  11   8  26.3   5.8  10.1  0.577  ...
# 7       Nikola Vučević   C   32  CHI  14  14  31.1   6.0  12.8  0.469  ...
# 8   Wendell Carter Jr.   C   23  ORL  13  13  32.8   5.6  11.2  0.503  ...
# 9          Brook Lopez   C   34  MIL  12  12  31.3   6.1  12.5  0.487  ...
# 10       Deandre Ayton   C   24  PHO  10  10  26.6   6.4  11.5  0.557  ...
#
#       FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 1   0.831  1.6  8.5  10.1  4.1  0.6  1.8  4.2  3.4  32.3
# 2   0.725  1.8  7.6   9.3  7.7  0.9  0.6  2.7  3.1  24.8
# 3   0.786  3.6  7.6  11.2  2.5  1.3  1.8  1.6  3.1  24.3
# 4   0.875  1.5  7.9   9.5  8.9  1.5  0.6  3.2  2.7  20.8
# 5   0.855  2.2  6.9   9.1  3.5  1.2  0.8  3.6  3.5  18.2
# 6   0.793  3.7  5.4   9.1  2.0  0.7  1.0  1.9  3.4  16.1
# 7   0.914  2.6  8.9  11.5  2.9  0.2  0.8  2.4  2.4  16.0
# 8   0.842  2.2  7.2   9.5  3.1  0.6  0.5  2.5  3.3  16.0
# 9   0.789  2.2  4.3   6.4  1.0  0.7  2.7  1.7  2.6  15.8
# 10  0.737  2.2  5.1   7.3  1.5  0.6  0.6  2.1  3.2  14.5
#
# [10 rows x 29 columns]

# %%
centers = df_stats[df_stats.Pos == 'C']
top_players(centers,'PTS')
# Out:
#                 Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 1          Joel Embiid   C   28  PHI  10  10  35.2  10.8  20.1  0.537  ...
# 2        Pascal Siakam   C   28  TOR   9   9  35.7   8.9  18.6  0.479  ...
# 3        Anthony Davis   C   29  LAL  12  12  34.5   9.7  17.8  0.542  ...
# 4         Nikola Jokić   C   27  DEN  13  13  31.1   7.9  13.1  0.606  ...
# 5          Bam Adebayo   C   25  MIA  13  13  34.9   7.3  13.7  0.534  ...
# 6       Alperen Şengün   C   20  HOU  11   8  26.3   5.8  10.1  0.577  ...
# 7       Nikola Vučević   C   32  CHI  14  14  31.1   6.0  12.8  0.469  ...
# 8   Wendell Carter Jr.   C   23  ORL  13  13  32.8   5.6  11.2  0.503  ...
# 9          Brook Lopez   C   34  MIL  12  12  31.3   6.1  12.5  0.487  ...
# 10       Deandre Ayton   C   24  PHO  10  10  26.6   6.4  11.5  0.557  ...
#
#       FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 1   0.831  1.6  8.5  10.1  4.1  0.6  1.8  4.2  3.4  32.3
# 2   0.725  1.8  7.6   9.3  7.7  0.9  0.6  2.7  3.1  24.8
# 3   0.786  3.6  7.6  11.2  2.5  1.3  1.8  1.6  3.1  24.3
# 4   0.875  1.5  7.9   9.5  8.9  1.5  0.6  3.2  2.7  20.8
# 5   0.855  2.2  6.9   9.1  3.5  1.2  0.8  3.6  3.5  18.2
# 6   0.793  3.7  5.4   9.1  2.0  0.7  1.0  1.9  3.4  16.1
# 7   0.914  2.6  8.9  11.5  2.9  0.2  0.8  2.4  2.4  16.0
# 8   0.842  2.2  7.2   9.5  3.1  0.6  0.5  2.5  3.3  16.0
# 9   0.789  2.2  4.3   6.4  1.0  0.7  2.7  1.7  2.6  15.8
# 10  0.737  2.2  5.1   7.3  1.5  0.6  0.6  2.1  3.2  14.5
#
# [10 rows x 29 columns]

# %% [markdown]
# ### Top 10 Guards

# %%
guards = df_stats[(df_stats.Pos == 'PG') | (df_stats.Pos == 'SG') ]
top_players(guards,'PTS')
# Out:
#                      Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# 1               Luka Dončić  PG   23  DAL  12  12  36.9  11.7  23.5  0.496
# 2             Stephen Curry  PG   34  GSW  12  12  35.2  11.0  20.9  0.526
# 3          Donovan Mitchell  SG   26  CLE  11  11  39.1  11.2  21.8  0.513
# 4   Shai Gilgeous-Alexander  SG   24  OKC  12  12  35.9  11.5  21.2  0.543
# 5                 Ja Morant  PG   23  MEM  12  12  32.9  10.1  21.0  0.480
# 6                Trae Young  PG   24  ATL  12  12  35.2   8.6  22.7  0.379
# 7              Devin Booker  SG   26  PHO  12  12  36.4   9.4  19.8  0.475
# 8              De'Aaron Fox  PG   25  SAC  11  11  32.7   9.8  17.9  0.548
# 9              Desmond Bane  SG   24  MEM  12  12  33.6   8.3  17.8  0.465
# 10             Tyrese Maxey  SG   22  PHI  14  14  37.5   8.4  18.6  0.448
#
#     ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 1   ...  0.748  1.0  7.7  8.7  8.1  2.0  0.7  3.3  3.3  34.3
# 2   ...  0.918  0.7  6.1  6.8  6.5  1.1  0.1  2.7  2.1  32.8
# 3   ...  0.875  1.0  3.7  4.7  6.1  1.4  0.6  3.4  2.9  31.6
# 4   ...  0.934  0.8  3.6  4.4  5.7  2.1  1.5  3.3  2.5  31.1
# 5   ...  0.788  1.1  4.9  6.0  7.0  1.0  0.3  4.0  1.9  28.8
# 6   ...  0.905  0.9  2.3  3.2  9.3  0.8  0.2  3.8  1.4  27.4
# 7   ...  0.868  0.9  3.6  4.5  5.6  1.0  0.4  2.8  2.3  26.7
# 8   ...  0.830  0.6  4.5  5.1  6.0  1.3  0.5  3.2  2.9  25.5
# 9   ...  0.912  0.5  4.4  4.9  4.8  0.6  0.3  2.3  2.4  24.7
# 10  ...  0.750  0.4  3.0  3.4  4.4  1.1  0.2  2.1  2.5  22.8
#
# [10 rows x 29 columns]

# %% [markdown]
# ### Top 10 Forward

# %%
forward = df_stats[(df_stats.Pos == 'PF') | (df_stats.Pos == 'SF')]
top_players(forward,'PTS')
# Out:
#                    Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 1            Jayson Tatum  PF   24  BOS  13  13  37.5  10.4  20.8  0.500  ...
# 2   Giannis Antetokounmpo  PF   28  MIL   9   9  32.8  11.4  21.1  0.542  ...
# 3            Kevin Durant  PF   34  BRK  14  14  37.0  10.2  19.5  0.524  ...
# 4            Jaylen Brown  SF   26  BOS  12  12  36.4   9.3  19.5  0.479  ...
# 5            LeBron James  PF   38  LAL  10  10  35.7  10.0  21.9  0.457  ...
# 6             Paul George  SF   32  LAC  12  12  35.7   8.8  18.9  0.463  ...
# 7           DeMar DeRozan  SF   33  CHI  14  14  33.8   8.1  16.0  0.509  ...
# 8          Keldon Johnson  SF   23  SAS  12  12  33.9   8.0  17.3  0.462  ...
# 9          Paolo Banchero  PF   20  ORL  11  11  34.6   8.1  17.5  0.461  ...
# 10        Zion Williamson  PF   22  NOP  11  11  32.2   9.0  15.9  0.566  ...
#
#       FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 1   0.872  0.8   6.5   7.2  4.1  0.8  1.3  2.5  2.2  32.3
# 2   0.649  1.9  10.3  12.2  5.3  1.1  1.4  3.3  2.9  31.8
# 3   0.915  0.4   6.2   6.6  5.3  0.9  1.9  3.3  2.5  30.6
# 4   0.847  1.0   5.8   6.8  3.3  0.8  0.5  2.9  2.8  25.3
# 5   0.667  1.8   7.0   8.8  6.9  1.1  0.7  3.4  2.0  24.9
# 6   0.839  0.4   5.5   5.9  4.5  1.5  0.6  3.6  2.7  24.7
# 7   0.887  0.4   3.6   3.9  4.2  1.1  0.4  2.3  2.6  23.9
# 8   0.767  0.7   4.6   5.3  3.7  1.0  0.1  3.0  1.7  23.6
# 9   0.769  0.8   7.5   8.3  3.6  0.7  0.9  3.0  2.4  23.5
# 10  0.716  2.1   4.3   6.4  3.9  1.1  0.3  2.7  2.7  23.5
#
# [10 rows x 29 columns]

# %% [markdown]
# ## Top 10 AST

# %%
top_players(df_stats,'AST')
# Out:
#                Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 1   Tyrese Haliburton  PG   22  IND  12  12  34.2   7.3  15.0  0.483  ...
# 2        James Harden  SG   33  PHI   9   9  36.8   7.0  15.9  0.441  ...
# 3          Chris Paul  PG   37  PHO  10  10  30.2   2.8   7.6  0.368  ...
# 4          Trae Young  PG   24  ATL  12  12  35.2   8.6  22.7  0.379  ...
# 5        Nikola Jokić   C   27  DEN  13  13  31.1   7.9  13.1  0.606  ...
# 6         Luka Dončić  PG   23  DAL  12  12  36.9  11.7  23.5  0.496  ...
# 7         Mike Conley  PG   35  UTA  14  14  30.3   3.6   9.1  0.398  ...
# 8     Dejounte Murray  SG   26  ATL  13  13  36.6   8.8  19.5  0.455  ...
# 9        Jrue Holiday  PG   32  MIL  10  10  33.1   7.4  16.8  0.440  ...
# 10      Pascal Siakam   C   28  TOR   9   9  35.7   8.9  18.6  0.479  ...
#
#       FT%  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS
# 1   0.857  1.1  3.7  4.8  10.3  1.8  0.2  3.0  1.3  20.5
# 2   0.929  0.6  6.4  7.0  10.0  1.1  0.7  2.9  2.0  22.0
# 3   0.882  0.5  4.0  4.5   9.4  1.7  0.2  1.5  2.3   9.5
# 4   0.905  0.9  2.3  3.2   9.3  0.8  0.2  3.8  1.4  27.4
# 5   0.875  1.5  7.9  9.5   8.9  1.5  0.6  3.2  2.7  20.8
# 6   0.748  1.0  7.7  8.7   8.1  2.0  0.7  3.3  3.3  34.3
# 7   0.759  0.4  1.9  2.3   8.1  1.0  0.3  1.6  1.6  10.8
# 8   0.871  0.9  5.4  6.3   8.0  2.2  0.5  2.4  1.8  21.7
# 9   0.857  1.3  4.4  5.7   7.9  1.5  0.7  2.9  1.7  19.6
# 10  0.725  1.8  7.6  9.3   7.7  0.9  0.6  2.7  3.1  24.8
#
# [10 rows x 29 columns]

# %% [markdown]
# ## Top 10 PTS

# %%
top_players(df_stats,'PTS')
# Out:
#                      Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# 1               Luka Dončić  PG   23  DAL  12  12  36.9  11.7  23.5  0.496
# 2             Stephen Curry  PG   34  GSW  12  12  35.2  11.0  20.9  0.526
# 3              Jayson Tatum  PF   24  BOS  13  13  37.5  10.4  20.8  0.500
# 4               Joel Embiid   C   28  PHI  10  10  35.2  10.8  20.1  0.537
# 5     Giannis Antetokounmpo  PF   28  MIL   9   9  32.8  11.4  21.1  0.542
# 6          Donovan Mitchell  SG   26  CLE  11  11  39.1  11.2  21.8  0.513
# 7   Shai Gilgeous-Alexander  SG   24  OKC  12  12  35.9  11.5  21.2  0.543
# 8              Kevin Durant  PF   34  BRK  14  14  37.0  10.2  19.5  0.524
# 9                 Ja Morant  PG   23  MEM  12  12  32.9  10.1  21.0  0.480
# 10               Trae Young  PG   24  ATL  12  12  35.2   8.6  22.7  0.379
#
#     ...    FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 1   ...  0.748  1.0   7.7   8.7  8.1  2.0  0.7  3.3  3.3  34.3
# 2   ...  0.918  0.7   6.1   6.8  6.5  1.1  0.1  2.7  2.1  32.8
# 3   ...  0.872  0.8   6.5   7.2  4.1  0.8  1.3  2.5  2.2  32.3
# 4   ...  0.831  1.6   8.5  10.1  4.1  0.6  1.8  4.2  3.4  32.3
# 5   ...  0.649  1.9  10.3  12.2  5.3  1.1  1.4  3.3  2.9  31.8
# 6   ...  0.875  1.0   3.7   4.7  6.1  1.4  0.6  3.4  2.9  31.6
# 7   ...  0.934  0.8   3.6   4.4  5.7  2.1  1.5  3.3  2.5  31.1
# 8   ...  0.915  0.4   6.2   6.6  5.3  0.9  1.9  3.3  2.5  30.6
# 9   ...  0.788  1.1   4.9   6.0  7.0  1.0  0.3  4.0  1.9  28.8
# 10  ...  0.905  0.9   2.3   3.2  9.3  0.8  0.2  3.8  1.4  27.4
#
# [10 rows x 29 columns]

# %% [markdown]
# ## TOP 10 3P
# #### 3-Point Field Goals Per Game

# %%
top_players(df_stats,'3P',['Player','3P','3PA','3P%','PTS','2P','FT','G','Tm','Age'])
# Out:
#                 Player   3P   3PA    3P%   PTS   2P   FT   G   Tm  Age
# 1        Stephen Curry  5.2  11.9  0.434  32.8  5.8  5.6  12  GSW   34
# 2     Donovan Mitchell  4.2   9.6  0.434  31.6  7.0  5.1  11  CLE   26
# 3          Buddy Hield  4.1  10.0  0.408  18.8  2.8  1.1  12  IND   30
# 4         Desmond Bane  3.8   8.5  0.451  24.7  4.4  4.3  12  MEM   24
# 5       Keldon Johnson  3.8   8.8  0.429  23.6  4.3  3.8  12  SAS   23
# 6      Anfernee Simons  3.8  10.5  0.365  22.3  3.9  3.0  11  POR   23
# 7        Kevin Huerter  3.8   7.3  0.511  16.6  1.8  1.8  12  SAC   24
# 8         Jayson Tatum  3.7   9.5  0.387  32.3  6.7  7.8  13  BOS   24
# 9   Michael Porter Jr.  3.6   7.4  0.483  18.0  2.9  1.4  12  DEN   24
# 10       Fred VanVleet  3.5   8.3  0.422  18.4  2.5  2.9  10  TOR   28

# %% [markdown]
# ## TOP 5 3P%
# #### Only players over the mean of 3PA

# %%
mean_3pp = df_stats['3PA'].mean()
df_3pp = df_stats[df_stats['3PA'] > mean_3pp]

# %%
top_players(df_3pp,'3P%',['Player','3P%','3PA','3P','PTS','2P','FT','G','Tm'],5)
# Out:
#                      Player    3P%  3PA   3P   PTS   2P   FT   G   Tm
# 1  Kentavious Caldwell-Pope  0.545  4.6  2.5  11.8  1.7  1.0  12  DEN
# 2             Kevin Huerter  0.511  7.3  3.8  16.6  1.8  1.8  12  SAC
# 3              Bones Hyland  0.500  5.8  2.9  14.0  1.6  2.2   9  DEN
# 4        Michael Porter Jr.  0.483  7.4  3.6  18.0  2.9  1.4  12  DEN
# 5                Al Horford  0.478  4.6  2.2  11.2  2.1  0.4  10  BOS

# %% [markdown]
# ## TOP 10 2P
# #### 2-Point Field Goals Per Game

# %%
top_players(df_stats,'2P',['Player','2P','2PA','2P%','PTS','3P','FT','G','Tm'])
# Out:
#                      Player    2P   2PA    2P%   PTS   3P   FT   G   Tm
# 1     Giannis Antetokounmpo  10.6  17.8  0.594  31.8  0.9  8.0   9  MIL
# 2   Shai Gilgeous-Alexander  10.5  18.4  0.570  31.1  1.0  7.1  12  OKC
# 3               Joel Embiid   9.9  16.3  0.607  32.3  0.9  9.8  10  PHI
# 4             Anthony Davis   9.3  16.5  0.566  24.3  0.3  4.6  12  LAL
# 5               Luka Dončić   9.3  15.3  0.609  34.3  2.3  8.7  12  DAL
# 6           Zion Williamson   8.7  15.4  0.568  23.5  0.3  5.3  11  NOP
# 7              Kevin Durant   8.5  14.7  0.578  30.6  1.7  8.4  14  BRK
# 8              LeBron James   8.3  14.8  0.561  24.9  1.7  3.2  10  LAL
# 9                 Ja Morant   8.0  15.9  0.503  28.8  2.1  6.5  12  MEM
# 10             De'Aaron Fox   7.9  12.8  0.617  25.5  1.9  4.0  11  SAC

# %% [markdown]
# ## TOP 5 2P%
# #### Only players over the mean of 2PA

# %%
mean_2pp = df_stats['2PA'].mean()
df_2pp = df_stats[df_stats['2PA'] > mean_2pp]

# %%
top_players(df_2pp,'2P%',['Player','2P%','2PA','2P','PTS','3P','FT','G','Tm'],5)
# Out:
#             Player    2P%   2PA   2P   PTS   3P   FT   G   Tm
# 1      Nic Claxton  0.731   7.4  5.4  11.9  0.0  1.1  14  BRK
# 2  Larry Nance Jr.  0.687   5.6  3.8   9.3  0.3  0.7  12  NOP
# 3     Aaron Gordon  0.678   6.9  4.7  14.5  0.8  2.5  13  DEN
# 4   Brandon Clarke  0.675   5.7  3.9   9.6  0.0  1.9  14  MEM
# 5     Nikola Jokić  0.669  10.9  7.3  20.8  0.6  4.3  13  DEN

# %% [markdown]
# ## TOP 5 FT
# #### Free Throws Goals Per Game

# %%
top_players(df_stats,'FT',['Player','FT','FTA','FT%','PTS','3P','2P','G','Tm'])
# Out:
#                      Player   FT   FTA    FT%   PTS   3P    2P   G   Tm
# 1               Joel Embiid  9.8  11.8  0.831  32.3  0.9   9.9  10  PHI
# 2               Luka Dončić  8.7  11.6  0.748  34.3  2.3   9.3  12  DAL
# 3              Kevin Durant  8.4   9.2  0.915  30.6  1.7   8.5  14  BRK
# 4     Giannis Antetokounmpo  8.0  12.3  0.649  31.8  0.9  10.6   9  MIL
# 5                Trae Young  7.9   8.8  0.905  27.4  2.3   6.3  12  ATL
# 6              Jayson Tatum  7.8   9.0  0.872  32.3  3.7   6.7  13  BOS
# 7              Jimmy Butler  7.4   8.3  0.890  22.1  0.9   6.0  11  MIA
# 8             DeMar DeRozan  7.3   8.2  0.887  23.9  0.3   7.9  14  CHI
# 9   Shai Gilgeous-Alexander  7.1   7.6  0.934  31.1  1.0  10.5  12  OKC
# 10                Ja Morant  6.5   8.3  0.788  28.8  2.1   8.0  12  MEM

# %% [markdown]
# ## TOP 10 2P%
# #### Only players over the mean of FTA

# %%
mean_2pp = df_stats['FTA'].mean()
df_2pp = df_stats[df_stats['FTA'] > mean_2pp]

# %%
top_players(df_stats,'FT%',['Player','FT%','FTA','FT','PTS','3P','2P','G','Tm'])
# Out:
#                Player  FT%  FTA   FT   PTS   3P   2P   G   Tm
# 1        Jake LaRavia  1.0  0.5  0.5   5.5  1.2  0.7  11  MEM
# 2          AJ Griffin  1.0  0.3  0.3   6.9  1.2  1.4   9  ATL
# 3       Georges Niang  1.0  0.5  0.5   8.4  2.1  0.7  14  PHI
# 4   Jordan McLaughlin  1.0  0.5  0.5   3.2  0.2  1.1  12  MIN
# 5     Andrew Nembhard  1.0  0.5  0.5   6.6  1.3  1.2  11  IND
# 6       Marcus Morris  1.0  0.6  0.6  14.7  2.3  3.6  11  LAC
# 7        Jordan Nwora  1.0  1.1  1.1   5.8  0.9  1.0  12  MIL
# 8        Derrick Rose  1.0  0.5  0.5   6.2  0.9  1.5  13  NYK
# 9        Anthony Gill  1.0  0.5  0.5   3.8  0.2  1.5  13  WAS
# 10         Isaiah Joe  1.0  0.4  0.4   3.8  0.8  0.5  10  OKC

# %% [markdown]
# ## DEFENSIVE STATS

# %%
def_stats = ['Player','BLK','STL','TRB','DRB','ORB','G','Tm']

# %% [markdown]
# ### TOP 10 BLK

# %%
top_players(df_stats,'BLK',def_stats)
# Out:
#                Player  BLK  STL   TRB  DRB  ORB   G   Tm
# 1         Brook Lopez  2.7  0.7   6.4  4.3  2.2  12  MIL
# 2         Ivica Zubac  2.2  0.6  11.2  8.4  2.8  13  LAC
# 3         Nic Claxton  2.1  0.8   9.1  6.1  2.9  14  BRK
# 4   Mitchell Robinson  2.0  0.3   5.7  2.6  3.1   9  NYK
# 5             Bol Bol  1.9  0.2   7.5  6.2  1.3  13  ORL
# 6        Kevin Durant  1.9  0.9   6.6  6.2  0.4  14  BRK
# 7     Bismack Biyombo  1.8  0.2   3.5  2.7  0.8  10  PHO
# 8       Anthony Davis  1.8  1.3  11.2  7.6  3.6  12  LAL
# 9         Joel Embiid  1.8  0.6  10.1  8.5  1.6  10  PHI
# 10     Walker Kessler  1.7  0.2   5.3  3.0  2.3  12  UTA

# %% [markdown]
# ### TOP 10 STL

# %%
top_players(df_stats,'STL',def_stats)
# Out:
#                      Player  BLK  STL  TRB  DRB  ORB   G   Tm
# 1                OG Anunoby  0.9  2.9  6.1  4.7  1.4  14  TOR
# 2             Fred VanVleet  0.7  2.3  3.7  3.1  0.6  10  TOR
# 3           Dejounte Murray  0.5  2.2  6.3  5.4  0.9  13  ATL
# 4   Shai Gilgeous-Alexander  1.5  2.1  4.4  3.6  0.8  12  OKC
# 5               Luka Dončić  0.7  2.0  8.7  7.7  1.0  12  DAL
# 6              Jimmy Butler  0.2  1.9  6.5  4.5  2.0  11  MIA
# 7          Dennis Smith Jr.  0.6  1.9  3.6  2.9  0.7  13  CHO
# 8         Tyrese Haliburton  0.2  1.8  4.8  3.7  1.1  12  IND
# 9                Chris Paul  0.2  1.7  4.5  4.0  0.5  10  PHO
# 10            Tobias Harris  0.6  1.6  6.2  5.1  1.1  14  PHI

# %% [markdown]
# ### TOP 10 TOTAL REBOUNDS PER GAME

# %%
top_players(df_stats,'TRB',def_stats)
# Out:
#                    Player  BLK  STL   TRB   DRB  ORB   G   Tm
# 1             Rudy Gobert  1.6  0.6  12.9   8.8  4.2  12  MIN
# 2   Giannis Antetokounmpo  1.4  1.1  12.2  10.3  1.9   9  MIL
# 3            Clint Capela  1.5  0.7  12.0   7.8  4.2  13  ATL
# 4           Jarrett Allen  1.3  0.4  11.5   8.0  3.5  12  CLE
# 5          Nikola Vučević  0.8  0.2  11.5   8.9  2.6  14  CHI
# 6            Steven Adams  1.2  0.8  11.4   6.2  5.2  13  MEM
# 7        Domantas Sabonis  0.5  0.9  11.3   8.8  2.6  12  SAC
# 8            Jusuf Nurkić  0.8  0.9  11.2   8.1  3.1  10  POR
# 9             Ivica Zubac  2.2  0.6  11.2   8.4  2.8  13  LAC
# 10          Anthony Davis  1.8  1.3  11.2   7.6  3.6  12  LAL

# %% [markdown]
# ### TOP 10 DEFENSIVE REBOUNDS PER GAME

# %%
top_players(df_stats,'DRB',def_stats)
# Out:
#                    Player  BLK  STL   TRB   DRB  ORB   G   Tm
# 1   Giannis Antetokounmpo  1.4  1.1  12.2  10.3  1.9   9  MIL
# 2          Nikola Vučević  0.8  0.2  11.5   8.9  2.6  14  CHI
# 3        Domantas Sabonis  0.5  0.9  11.3   8.8  2.6  12  SAC
# 4             Rudy Gobert  1.6  0.6  12.9   8.8  4.2  12  MIN
# 5             Joel Embiid  1.8  0.6  10.1   8.5  1.6  10  PHI
# 6             Ivica Zubac  2.2  0.6  11.2   8.4  2.8  13  LAC
# 7            Bobby Portis  0.3  0.4  11.0   8.3  2.8  12  MIL
# 8            Jusuf Nurkić  0.8  0.9  11.2   8.1  3.1  10  POR
# 9           Jarrett Allen  1.3  0.4  11.5   8.0  3.5  12  CLE
# 10           Nikola Jokić  0.6  1.5   9.5   7.9  1.5  13  DEN

# %% [markdown]
# ### TOP 10 OFFENSIVE REBOUNDS PER GAME

# %%
top_players(df_stats,'ORB',def_stats,10)
# Out:
#                 Player  BLK  STL   TRB  DRB  ORB   G   Tm
# 1         Steven Adams  1.2  0.8  11.4  6.2  5.2  13  MEM
# 2         Clint Capela  1.5  0.7  12.0  7.8  4.2  13  ATL
# 3          Rudy Gobert  1.6  0.6  12.9  8.8  4.2  12  MIN
# 4         Jakob Poeltl  1.2  1.0   9.8  6.0  3.8  13  SAS
# 5       Alperen Şengün  1.0  0.7   9.1  5.4  3.7  11  HOU
# 6   Isaiah Hartenstein  1.2  0.7   8.3  4.6  3.7  13  NYK
# 7        Anthony Davis  1.8  1.3  11.2  7.6  3.6  12  LAL
# 8        Jarrett Allen  1.3  0.4  11.5  8.0  3.5  12  CLE
# 9    Jonas Valančiūnas  0.3  0.5  10.1  6.8  3.3  13  NOP
# 10        Jusuf Nurkić  0.8  0.9  11.2  8.1  3.1  10  POR
